# %% [markdown]
# ## 安装依赖

# %%
# !pip install langchain langchain-community pydantic jq faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (1.0.5)
# Requirement already satisfied: langchain-community in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pydantic in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (2.12.4)
# Requirement already satisfied: jq in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (1.10.0)
# Requirement already satisfied: faiss-cpu in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (1.12.0)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (5.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain) (1.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-community) (2.3.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/vector_db/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %% [markdown]
# ## 创建示例数据

# %%
# =========================
# 1. 加载 JSON 数据
# =========================
import json

# 这里示范数据结构，实际可替换成你的 chat_history.json
json_data = [
    {
        "id": 1,
        "speaker": "用户A",
        "content": "昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。",
        "timestamp": "2025-05-01T10:00:00"
    },
    {
        "id": 2,
        "speaker": "用户B",
        "content": "是的，最初定的是下周五。但现在项目需求有所增加，我们最好推迟到后下周三。",
        "timestamp": "2025-05-01T10:05:00"
    },
    {
        "id": 3,
        "speaker": "用户A",
        "content": "后下周三？好的，这个时间我可以接受。我会在会议记录里更新。",
        "timestamp": "2025-05-01T10:10:00"
    }
]

# %% [markdown]
# ## Langchain加载数据、转换为doc对象

# %%
# =========================
# 2. LangChain 转换为 Document
# =========================
from langchain_core.documents import Document

documents = [
    Document(
        page_content=item["content"],
        metadata={
            "speaker": item["speaker"],
            "timestamp": item["timestamp"],
            "id": item["id"]
        }
    )
    for item in json_data
]

print(f"✅ 转换为 Document 完成，共 {len(documents)} 条记录")
print(documents[0].page_content, documents[0].metadata)
# Out:
# ✅ 转换为 Document 完成，共 3 条记录
# 昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。 {'speaker': '用户A', 'timestamp': '2025-05-01T10:00:00', 'id': 1}

# %% [markdown]
# ## chunking切分

# %%
# =========================
# 3. 文本 Chunking
# =========================
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,      # 每块最大字符数
    chunk_overlap=10,   # 重叠字符数
    separators=["\n\n", "\n", "。", "！", "？", " ", ""]
)

chunks = splitter.split_documents(documents)
print(f"✅ 文本切分完成，总共 {len(chunks)} 个 chunk")
for chunk in chunks:
    print(chunk.page_content, chunk.metadata)
    print(chunk,"\n")
# Out:
# ✅ 文本切分完成，总共 3 个 chunk
# 昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。 {'speaker': '用户A', 'timestamp': '2025-05-01T10:00:00', 'id': 1}
# page_content='昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。' metadata={'speaker': '用户A', 'timestamp': '2025-05-01T10:00:00', 'id': 1}
#
# 是的，最初定的是下周五。但现在项目需求有所增加，我们最好推迟到后下周三。 {'speaker': '用户B', 'timestamp': '2025-05-01T10:05:00', 'id': 2}
# page_content='是的，最初定的是下周五。但现在项目需求有所增加，我们最好推迟到后下周三。' metadata={'speaker': '用户B', 'timestamp': '2025-05-01T10:05:00', 'id': 2}
#
# 后下周三？好的，这个时间我可以接受。我会在会议记录里更新。 {'speaker': '用户A', 'timestamp': '2025-05-01T10:10:00', 'id': 3}
# page_content='后下周三？好的，这个时间我可以接受。我会在会议记录里更新。' metadata={'speaker': '用户A', 'timestamp': '2025-05-01T10:10:00', 'id': 3}

# %% [markdown]
# ## embedding成为句向量

# %%
# =========================
# 4. Embedding
# =========================
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(model_name="m3e-small")

# =========================
# 5. 转换成向量
# =========================
# FAISS 需要的就是直接把 Document 列表传入向量数据库，它会自动计算 embedding
# 但如果你想单独拿 vector，也可以：
vectors = [embedding_model.embed_documents([chunk.page_content])[0] for chunk in chunks]

# %% [markdown]
# ## 存入vectordb

# %%
# =========================
# 6. 存入向量数据库（FAISS）
# =========================
from langchain_community.vectorstores import FAISS

vector_db = FAISS.from_documents(chunks, embedding_model)

# 保存到本地
vector_db.save_local("chat_vector_db")
print("✅ 已保存向量数据库到 chat_vector_db/")
# Out:
# ✅ 已保存向量数据库到 chat_vector_db/

# %% [markdown]
# ## 测试topk检索

# %%
# =========================
# 7. 测试 top-k 检索
# =========================
query = "时间？"
results = vector_db.similarity_search(query, k=2)
print(results,"\n")
print("🔎 top-k 检索结果：")
for r in results:
    print(f"内容：{r.page_content}")
    print(f"说话者：{r.metadata['speaker']}, 时间：{r.metadata['timestamp']}")
    print("-" * 50)
# Out:
# [Document(id='f89cc412-6525-4faf-864d-11034d756f0b', metadata={'speaker': '用户A', 'timestamp': '2025-05-01T10:00:00', 'id': 1}, page_content='昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。'), Document(id='4882b0bd-bea8-4ccd-a657-509374da75a3', metadata={'speaker': '用户A', 'timestamp': '2025-05-01T10:10:00', 'id': 3}, page_content='后下周三？好的，这个时间我可以接受。我会在会议记录里更新。')]
#
# 🔎 top-k 检索结果：
# 内容：昨天我们讨论的那个项目截止日期定在什么时候？我记得是下周。
# 说话者：用户A, 时间：2025-05-01T10:00:00
# --------------------------------------------------
# 内容：后下周三？好的，这个时间我可以接受。我会在会议记录里更新。
# 说话者：用户A, 时间：2025-05-01T10:10:00
# --------------------------------------------------
